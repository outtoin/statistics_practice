# %%
from scipy import stats
import numpy as np
import pandas as pd
from statsmodels.stats.multicomp import pairwise_tukeyhsd, MultiComparison
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats as ss

from numpy.linalg import norm

import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import HTML,display

from ast import literal_eval as make_tuple

from os import listdir
from os.path import isfile, join, splitext, basename
import csv
import itertools
import glob

from util import csv_length

# %matplotlib inline

# %%
data_path = './data/deviation/'
t1_list = glob.glob(data_path + '*_t1.csv')
t2_list = glob.glob(data_path + '*_t2.csv')
com_list = glob.glob(data_path + '*_com.csv')

t1_num_list = [csv_length(data) for data in t1_list]
t2_num_list = [csv_length(data) for data in t2_list]
com_num_list = [csv_length(data) for data in com_list]

# %%
def ingest(data, nums):
    tmp = pd.read_csv(data, names = [i for i in range(nums)])
    tmp_sers = [tmp[i].dropna() for i in range(nums)]
    
    tmp_chkpoints = [ser[:ser[ser.str.contains('Score')].index[0]] for ser in tmp_sers]
    tmp_datas = [ser[ser[ser.str.contains('Score')].index[0]+1:] for ser in tmp_sers]
    tmp_scores = [ser[ser[ser.str.contains('Score')].index[0]] for ser in tmp_sers]
    
    return tmp_chkpoints, tmp_datas, tmp_scores

def make_arrays(sers):
    ret = [ser.apply(lambda x: np.array(make_tuple(x))) for ser in sers]
    return ret

def refine(sers):
    ret = [ser[(ser.apply(lambda x: x[2]) >= 0) & (ser.apply(lambda x: x[2]) <= 600)].reset_index(drop=True) for ser in sers]
    return ret
    

def find_dist(chkpoint, data):
    res_dict = {}
    res_list = []

    for i in range(len(chkpoint)):
        idx = min(range(len(data)), key=lambda j: abs(data[j][2]-chkpoint[i][2]))
        minidx = -5
        maxidx = 5
        if idx < 5:
            minidx = -idx
        if idx > len(data) - 5:
            maxidx = len(data)-idx
        new_idxs = np.arange(minidx, maxidx) + idx
        res_dict[i] = data.loc[new_idxs].values

    for key in res_dict.keys():
        for item in res_dict[key]:
            res_list.append(np.linalg.norm(chkpoint[key][:2] - item[:2]))
            
    return np.mean(res_list)

def score_to_list(scores):
    return [int(score.split(':')[-1]) for score in scores]

# %%
chkpoints, datas, scores = ingest(com_list[0], com_num_list[0])
score_to_list(scores)
# Out:
# [18, 15, 15]

# %%
def make_result(data, nums):
    chkpoints, datas, scores = ingest(data, nums)
    chkpoints, datas = make_arrays(chkpoints), make_arrays(datas)
    chkpoints, datas = refine(chkpoints), refine(datas)
    score_list = score_to_list(scores)
    result = [[find_dist(chkpoints[i], datas[i]), score_list[i]] for i in range(nums)]
    return result

# %%
make_result(com_list[1], com_num_list[1])
# Out:
# [[4.720565142896691, 22],
#  [4.512724893935976, 25],
#  [7.402794125129793, 18],
#  [5.748244166216569, 22],
#  [5.1855678724747465, 22]]

# %%
def ingest2(data, num):
    tmp = pd.read_csv(data, names=[i for i in range(num)])
    return [tmp[column].apply(lambda x: int(x.split(':')[-1])).values for column in tmp]

# %%
df = pd.read_csv(t2_list[0], names = [i for i in range(t2_num_list[0])])
for column in df:
    df[column].apply(lambda x: int(x.split(':')[-1])).values

# %%
t2_res_dict = {splitext(basename(data))[0]: ingest2(data, nums) for data, nums in zip(t2_list, t2_num_list)}

# %%
t2_res_dict
# Out:
# {'p10_t2': [array([40]), array([40]), array([40]), array([40]), array([40])],
#  'p1_t2': [array([40]), array([40]), array([39]), array([40]), array([39])],
#  'p2_t2': [array([39]), array([40]), array([39]), array([40]), array([40])],
#  'p3_t2': [array([39]), array([40]), array([38]), array([39]), array([40])],
#  'p5_t2': [array([40]), array([40]), array([38]), array([40]), array([39])],
#  'p7_t2': [array([40]), array([40]), array([39]), array([40]), array([40])],
#  'p8_t2': [array([39]), array([39]), array([40]), array([40]), array([37])],
#  'p9_t2': [array([40]), array([40]), array([39]), array([40]), array([38])]}

# %%
t1_res_com_res_dict = {splitext(basename(data))[0]: make_result(data, nums) for data, nums in zip(t1_list, t1_num_list)}dict = {splitext(basename(data))[0]: make_result(data, nums) for data, nums in zip(t1_list, t1_num_list)}
com_res_dict = {splitext(basename(data))[0]: make_result(data, nums) for data, nums in zip(t1_list, t1_num_list)}

# %%
com_res_dict = {splitext(basename(data))[0]: make_result(data, nums) for data, nums in zip(com_list, com_num_list)}

# %%
com_res_dict
# Out:
# {'p10_com': [[9.39029579603402, 17],
#   [5.999877499008621, 17],
#   [5.261191895346471, 22],
#   [5.828867367902421, 23],
#   [7.294952566685448, 17]],
#  'p2_com': [[6.317080742608382, 26],
#   [6.317080742608382, 26],
#   [6.951640596260343, 32],
#   [6.658250494282986, 34],
#   [7.329520876321976, 34]],
#  'p3_com': [[7.721822485360722, 21],
#   [7.729581016481224, 21],
#   [7.013154255231468, 28],
#   [9.093814463278202, 22],
#   [6.822291857351103, 23]],
#  'p5_com': [[6.124199442386478, 18],
#   [9.121894838457965, 15],
#   [7.893431062515279, 15]],
#  'p7_com': [[8.602892796144536, 15],
#   [5.594983713661252, 29],
#   [3.9091281531062596, 18],
#   [3.3534880548341865, 18],
#   [4.536952668649013, 21]],
#  'p9_com': [[5.9095928385394245, 29],
#   [7.713701231072887, 16],
#   [8.130159098872703, 23],
#   [9.193557568017653, 20],
#   [6.293319635808794, 23]],
#  't8_com': [[4.720565142896691, 22],
#   [4.512724893935976, 25],
#   [7.402794125129793, 18],
#   [5.748244166216569, 22],
#   [5.1855678724747465, 22]]}

# %%
com_list
# Out:
# ['./data/deviation/p5_com.csv',
#  './data/deviation/t8_com.csv',
#  './data/deviation/p3_com.csv',
#  './data/deviation/p7_com.csv',
#  './data/deviation/p9_com.csv',
#  './data/deviation/p10_com.csv',
#  './data/deviation/p2_com.csv']

# %%
com_res_dict['p2_']
# Out:
# dict_keys(['p9_t1', 'p10_t1', 'p2_t1', 'p7_t1', 'p3_t1', 'p5_t1', 'p8_t1'])

# %%
string ='p2_t1'
for i in range(len(res_dict[string])):
    df.loc[-1] = [string.split('_')[0][-1], 'T1', res_dict['p9_t1'][i], 0, i+1]
    df.index = df.index+1
    df = df.sort_index()
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-168-950de9e0b818> in <module>()
#       1 string ='p1_t1'
# ----> 2 for i in range(len(res_dict[string])):
#       3     df.loc[-1] = [string.split('_')[0][-1], 'T1', res_dict['p9_t1'][i], 0, i+1]
#       4     df.index = df.index+1
#       5     df = df.sort_index()
#
# KeyError: 'p1_t1'

# %%
df = pd.DataFrame(columns=['Participants No.', 'Task', 'Distance', 'Score', 'Trial'])
df
# Out:
# Empty DataFrame
# Columns: [Participants No., Task, Distance, Score, Trial]
# Index: []

# %%
t1_num_list[0]
# Out:
# 5

# %%
t1_list[0]
# Out:
# './data/deviation/p9_t1.csv'

# %%
[find_dist(chkpoints[3], datas[3])]
# Out:
# [4.09827200975125]

# %%
t1_res_dict = {splitext(basename(data))[0]: make_result(data, nums) for data, nums in zip(t1_list, t1_num_list)}
# Out:
# [0        [-3.924615, 21.44665, 14.99292]
# 1            [2.809, 29.29745, 43.13107]
# 2         [4.339758, 22.59884, 72.92099]
# 3          [8.975751, 24.04423, 102.899]
# 4         [4.496086, 29.98404, 131.9466]
# 5        [-2.903792, 17.89462, 158.8745]
# 6         [7.385743, 15.51435, 187.8897]
# 7        [-5.648148, 17.99056, 215.8902]
# 8        [-6.063065, 21.10863, 246.4083]
# 9       [0.05689099, 21.02533, 276.6189]
# 10        [5.770912, 18.57292, 306.8619]
# 11       [-5.802941, 17.74261, 335.4375]
# 12        [-3.063105, 27.10756, 364.368]
# 13        [7.777572, 25.58026, 392.7149]
# 14        [-3.803408, 30.4225, 418.8282]
# 15       [-3.672556, 26.59524, 445.8516]
# 16        [-2.846588, 19.6266, 475.1123]
# 17       [-1.004245, 17.74133, 505.1772]
# 18    [-0.003203675, 26.69716, 533.5602]
# 19        [2.837936, 33.26009, 561.7103]
# 20          [6.534966, 28.78083, 591.41]
# Name: 0, dtype: object, 0      [2.744862, 27.03364, 1.726585]
# 1       [6.36146, 24.03343, 31.96721]
# 2      [2.367036, 19.67836, 61.92709]
# 3     [0.5245939, 28.49314, 90.04472]
# 4     [-3.110354, 31.94689, 118.7308]
# 5     [-5.771859, 22.96613, 147.6536]
# 6     [-1.342231, 19.39399, 176.5481]
# 7      [3.250799, 23.54085, 206.6227]
# 8     [0.7928075, 22.46618, 236.8997]
# 9     [0.09104639, 26.94341, 265.454]
# 10     [1.975842, 33.45772, 294.2151]
# 11    [-2.248086, 32.64024, 324.4283]
# 12    [-3.030722, 33.04406, 353.8894]
# 13     [2.513625, 29.13703, 383.6946]
# 14      [3.213219, 28.45449, 414.093]
# 15       [6.022442, 32.141, 444.5572]
# 16      [6.82998, 27.21707, 474.0283]
# 17     [5.123971, 21.16988, 502.8823]
# 18     [5.224152, 27.36161, 533.0905]
# 19    [0.9338993, 27.67562, 561.8086]
# 20    [-3.902394, 19.70376, 589.2489]
# Name: 1, dtype: object, 0      [-7.856239, 23.28165, 10.31065]
# 1     [-0.9197811, 28.69053, 36.98926]
# 2        [7.89849, 19.99885, 62.67641]
# 3      [-2.898113, 27.66853, 90.03708]
# 4       [4.530218, 19.60763, 118.7951]
# 5      [-7.121253, 25.04785, 146.9878]
# 6       [5.184322, 19.31359, 173.8443]
# 7        [1.28476, 27.53905, 201.8009]
# 8     [-0.9429573, 30.27167, 231.8808]
# 9       [1.250555, 28.88209, 262.5917]
# 10     [-1.422979, 19.77218, 291.5878]
# 11      [6.606608, 16.87984, 320.1949]
# 12       [0.962115, 20.8219, 348.2096]
# 13       [-6.89775, 26.48316, 377.285]
# 14      [1.214909, 30.64126, 404.8566]
# 15      [7.310292, 29.64328, 433.0438]
# 16      [6.925447, 22.11147, 462.6162]
# 17      [7.027965, 21.47013, 491.6449]
# 18    [-0.1135994, 30.10623, 520.2587]
# 19     [-3.241749, 32.41955, 548.3431]
# 20      [2.085646, 27.84452, 576.8745]
# Name: 2, dtype: object, 0       [2.887275, 19.42804, 15.51742]
# 1       [0.212958, 22.04053, 45.22355]
# 2       [4.656956, 23.62461, 75.38652]
# 3       [2.671455, 23.45529, 106.1939]
# 4       [3.317526, 20.18055, 136.7474]
# 5        [1.87984, 18.24348, 166.4556]
# 6      [-4.140083, 23.03271, 196.1508]
# 7     [-0.4595937, 26.95643, 225.7949]
# 8       [7.127447, 28.67218, 254.6601]
# 9       [4.442869, 24.85801, 285.1441]
# 10      [2.356485, 23.09114, 315.9042]
# 11      [1.534624, 21.51777, 346.7325]
# 12     [-1.968517, 23.23779, 376.8622]
# 13     [-6.095347, 25.62529, 406.3476]
# 14     [-5.948204, 23.23051, 436.6763]
# 15     [-9.038649, 22.92334, 467.1223]
# 16     [-5.167432, 24.02387, 497.4195]
# 17     [-2.811475, 24.15865, 527.1574]
# 18    [-0.3036973, 21.28257, 555.8586]
# 19       [7.874624, 22.53649, 584.151]
# Name: 3, dtype: object, 0      [-9.353179, 23.45721, 8.023529]
# 1      [-3.266998, 17.74589, 37.22892]
# 2       [-4.931146, 19.46483, 67.1737]
# 3     [-0.4509201, 17.98396, 96.92101]
# 4      [-5.285151, 23.29404, 125.7846]
# 5      [-3.744801, 24.70182, 155.3224]
# 6       [5.558815, 29.40547, 184.0795]
# 7        [5.067585, 25.46807, 212.194]
# 8      [0.3494413, 17.75664, 241.5231]
# 9      [-3.872869, 22.87367, 270.3033]
# 10     [-6.744382, 25.06174, 298.7982]
# 11     [-0.2213144, 19.30754, 327.186]
# 12      [7.335765, 23.32558, 354.4035]
# 13      [1.071726, 29.93103, 381.1824]
# 14     [-8.930208, 17.32081, 405.9753]
# 15     [-2.500832, 32.31694, 432.3307]
# 16      [4.212362, 32.38733, 461.9814]
# 17     [-1.173054, 20.31118, 489.3987]
# 18       [5.89809, 21.73164, 517.9879]
# 19      [-2.930975, 19.9999, 545.4874]
# 20    [0.03981757, 23.59833, 572.9365]
# Name: 4, dtype: object]
# /home/lawfully1/.pyenv/versions/lawfully-3.6.2/lib/python3.6/site-packages/pandas/core/series.py:696: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self.loc[key]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-2efc0cf309eb> in <module>()
# ----> 1 t1_res_dict = {splitext(basename(data))[0]: make_result(data, nums) for data, nums in zip(t1_list, t1_num_list)}
#
# <ipython-input-95-2efc0cf309eb> in <dictcomp>(.0)
# ----> 1 t1_res_dict = {splitext(basename(data))[0]: make_result(data, nums) for data, nums in zip(t1_list, t1_num_list)}
#
# <ipython-input-94-872c35bea2b2> in make_result(data, nums)
#       4     chkpoints, datas = refine(chkpoints), refine(datas)
#       5     print(chkpoints)
# ----> 6     result = [find_dist(chkpoints[i], datas[i]) for i in range(nums)]
#       7
#       8     print(result)
#
# <ipython-input-94-872c35bea2b2> in <listcomp>(.0)
#       4     chkpoints, datas = refine(chkpoints), refine(datas)
#       5     print(chkpoints)
# ----> 6     result = [find_dist(chkpoints[i], datas[i]) for i in range(nums)]
#       7
#       8     print(result)
#
# <ipython-input-91-fc80ac6190db> in find_dist(chkpoint, data)
#      27     for key in res_dict.keys():
#      28         for item in res_dict[key]:
# ---> 29             res_list.append(np.linalg.norm(chkpoint[key][:2] - item[:2]))
#      30
#      31     return np.mean(res_list)
#
# TypeError: 'float' object is not subscriptable

# %%
t1_res_dict['p10_t1']
# Out:
# ([0        [-5.54975, 29.94616, 13.97997]
#   1       [0.3554421, 22.61518, 42.13364]
#   2       [-1.785244, 25.97851, 70.34202]
#   3       [-5.846662, 22.17454, 98.54153]
#   5343      [2.361916, 20.1412, 598.0507]
#   5344     [2.332223, 20.11905, 598.1694]
#   5345      [2.30455, 20.09691, 598.2783]
#   5346      [2.27612, 20.07477, 598.3884]
#   5347     [2.246158, 20.05263, 598.5026]
#   5348     [2.217517, 20.03048, 598.6099]
#   5349     [2.187407, 20.00834, 598.7211]
#   5350      [2.154774, 19.9862, 598.8397]
#   5351     [2.124328, 19.96406, 598.9487]
#   5352     [2.094579, 19.94191, 599.0536]
#   5353     [2.062683, 19.91977, 599.1647]
#   5354     [2.029026, 19.89763, 599.2804]
#   5355       [1.996701, 19.87549, 599.39]
#   5356     [1.962583, 19.85334, 599.5043]
#   5357       [1.92858, 19.8312, 599.6169]
#   5358     [1.893293, 19.80906, 599.7325]
#   5359      [1.860492, 19.78692, 599.839]
#   5360      [1.824758, 19.76477, 599.954]
#   Name: 1, Length: 5361, dtype: object, 0                [0.0, 20.0, 1.080016]
#   1       [0.01009602, 19.942, 1.294291]
#   2       [0.01472397, 19.876, 1.394439]
#   3       [0.01827411, 19.802, 1.471532]
#   4        [0.02820594, 19.72, 1.687266]
#   5        [0.03865483, 19.63, 1.907847]
#   6       [0.04389999, 19.532, 2.015034]
#   7       [0.04951569, 19.426, 2.128604]
#   8        [0.0551695, 19.312, 2.241697]
#   9        [0.06070188, 19.19, 2.351344]
#   10       [0.06644738, 19.06, 2.464386]
#   11      [0.07207596, 18.922, 2.574363]
#   12      [0.07803778, 18.776, 2.689802]
#   13       [0.08451917, 18.622, 2.81392]
#   14        [0.09103426, 18.46, 2.93701]
#   15       [0.09603156, 18.29, 3.030066]
#   16        [0.1015561, 18.112, 3.13186]
#   17        [0.1079126, 17.926, 3.24757]
#   18        [0.1151242, 17.732, 3.37706]
#   19        [0.1204474, 17.53, 3.471308]
#   20       [0.1268082, 17.328, 3.583015]
#   21       [0.1330138, 17.126, 3.691172]
#   22       [0.1394791, 16.924, 3.803164]
#   23        [0.1458741, 16.722, 3.91354]
#   24        [0.1522924, 16.52, 4.024112]
#   25       [0.1588507, 16.318, 4.137011]
#   26       [0.1653723, 16.116, 4.249224]
#   27       [0.1729068, 15.914, 4.379011]
#   28       [0.1797054, 15.712, 4.496466]
#   29        [0.1850227, 15.51, 4.588655]
#                        ...
#   5330    [6.624102, 28.05841, 596.7114]
#   5331     [6.608077, 28.0338, 596.8253]
#   5332    [6.593326, 28.00918, 596.9319]
#   5333    [6.577909, 27.98456, 597.0456]
#   5334    [6.562866, 27.95994, 597.1591]
#   5335    [6.549346, 27.93532, 597.2637]
#   5336    [6.534886, 27.91071, 597.3787]
#   5337    [6.520997, 27.88609, 597.4926]
#   5338    [6.507158, 27.86147, 597.6099]
#   5339     [6.495329, 27.83685, 597.714]
#   5340     [6.48285, 27.81223, 597.8276]
#   5341    [6.471119, 27.78761, 597.9387]
#   5342      [6.459408, 27.763, 598.0542]
#   5343    [6.448921, 27.73838, 598.1621]
#   5344    [6.438274, 27.71376, 598.2763]
#   5345    [6.428598, 27.68914, 598.3849]
#   5346     [6.41818, 27.62453, 598.5071]
#   5347    [6.409595, 27.55991, 598.6132]
#   5348    [6.400868, 27.49529, 598.7258]
#   5353        [-1.378529, 23.7952, 599.388]
#   5354      [-1.422318, 23.77029, 599.5047]
#   5355      [-1.465759, 23.74538, 599.6213]
#   5356      [-1.506561, 23.72047, 599.7318]
#   5357      [-1.543488, 23.69556, 599.8325]
#   5358      [-1.587046, 23.67066, 599.9522]
#   Name: 3, Length: 5359, dtype: object, 0                 [0.0, 20.0, 1.142813]
#   1       [0.004509077, 19.942, 1.341995]
#   2       [0.007317236, 19.876, 1.465837]
#   3       [0.009807523, 19.802, 1.574515]
#   4         [0.01530925, 19.72, 1.811759]
#   5         [0.02105409, 19.63, 2.048397]
#   6        [0.02337017, 19.532, 2.140431]
#   7         [0.0260258, 19.426, 2.244987]
#   8         [0.0288462, 19.312, 2.354988]
#   9         [0.03156954, 19.19, 2.460412]
#   10         [0.0345502, 19.06, 2.575142]
#   11       [0.03747427, 18.922, 2.686932]
#   12       [0.04045581, 18.776, 2.799856]
#   13        [0.0433458, 18.622, 2.907977]
#   14        [0.04649954, 18.46, 3.024374]
#   15        [0.04967111, 18.29, 3.139412]
#   16       [0.05265297, 18.112, 3.245672]
#   17       [0.05599967, 17.926, 3.362878]
#   18        [0.05937526, 17.732, 3.47847]
#   19        [0.06254506, 17.53, 3.584574]
#   20        [0.0657122, 17.328, 3.688339]
#   21       [0.06932107, 17.126, 3.804026]
#   22       [0.07294203, 16.924, 3.917363]
#   23       [0.07650844, 16.722, 4.026541]
#   24         [0.0803057, 16.52, 4.140464]
#   25       [0.08404031, 16.318, 4.250291]
#   26       [0.08791868, 16.116, 4.362491]
#   27       [0.09193882, 15.914, 4.477128]
#   28       [0.09646785, 15.712, 4.604715]
#   29        [0.09999741, 15.51, 4.703088]
#                        ...
#   5329     [1.596705, 25.19745, 596.7156]
#   5330     [1.583195, 25.17272, 596.8266]
#   5331     [1.569917, 25.14799, 596.9343]
#   5332      [1.555771, 25.12327, 597.048]
#   5333      [1.540954, 25.09854, 597.166]
#   5334      [1.527262, 25.07381, 597.274]
#   5335     [1.513249, 25.05648, 597.3838]
#   5336      [1.49897, 24.99961, 597.4946]
#   5337      [1.483391, 24.94485, 597.614]
#   5338     [1.469321, 24.89395, 597.7201]
#   5339     [1.454342, 24.84868, 597.8315]
#   5340     [1.439332, 24.81077, 597.9417]
#   5341      [1.423936, 24.7814, 598.0535]
#   5342     [1.407767, 24.76284, 598.1699]
#   5343     [1.391901, 24.74813, 598.2831]
#   5344     [1.376798, 24.73856, 598.3901]
#   5345     [1.361085, 24.73497, 598.5005]
#   5346     [1.345325, 24.73754, 598.6105]
#   5347       [1.32781, 24.7457, 598.7316]
#   5348     [1.311997, 24.75793, 598.8398]
#   5349      [1.29543, 24.77202, 598.9523]
#   5350      [1.279407, 24.7855, 599.0604]
#   5351     [1.262827, 24.79676, 599.1719]
#   5352     [1.245838, 24.80363, 599.2861]
#   5353     [1.228233, 24.80406, 599.4048]
#   5354     [1.213126, 24.79605, 599.5073]
#   5355      [1.196761, 24.77814, 599.619]
#   5356     [1.180289, 24.74765, 599.7324]
#   5357     [1.164381, 24.70311, 599.8428]
#   5358     [1.148695, 24.64383, 599.9522]
#   Name: 4, Length: 5359, dtype: object])
